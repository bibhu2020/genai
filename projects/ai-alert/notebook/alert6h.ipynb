# %% [markdown]
# ### KPI - Availability (Sev3: Burn Velocity > 2x in 6 hrs windows)

# %%
#! pip install azure-identity azure-monitor-query langchain-openai

# %%
## Get the credential to query log analytics
from azure.identity import DefaultAzureCredential
from azure.monitor.query import LogsQueryClient, LogsQueryStatus
import pandas as pd

# Azure config
tenant_id = "72f988bf-86f1-41af-91ab-2d7cd011db47"
workspace_id = "edf08e1f-916f-48c3-bc52-273492d63c8f"

# Auth
credential = DefaultAzureCredential()
client = LogsQueryClient(credential)

# %%
# Calculate the Burn Rate for slo = 99.95% in 5 minutes window
# Fire this alert in every 5 minutes

slo = 0.9995
timeGrain = "6h"

query = f"""

let SLO = {slo};
let timeGrain = {timeGrain};
AzureDiagnostics
| where TimeGenerated > ago(30d)
  and Resource == "MSONECLOUDAPIFD"
  and Category == "FrontDoorAccessLog"
| where isnotempty(httpStatusCode_s)
| extend statusCode = toint(httpStatusCode_s)
| summarize
    totalRequests = count(),
    errorRequests = countif(statusCode >= 500)
    by bin(TimeGenerated, timeGrain)
| extend SLI = iff(totalRequests > 0, 1.0 - (1.0 * errorRequests / totalRequests), 1.0)
| extend burnRate = iff(totalRequests > 0, (1.0 - SLI) / (1.0 - SLO), 0.0)
| project TimeGenerated, totalRequests, errorRequests, SLI, burnRate
| order by TimeGenerated asc
"""

# Query execution
response = client.query_workspace(
    workspace_id=workspace_id,
    query=query,
    timespan=None
)

# Parse results
if response.status == LogsQueryStatus.SUCCESS:
    table = response.tables[0]
    df = pd.DataFrame(data=table.rows, columns=table.columns)
    df["TimeGenerated"] = pd.to_datetime(df["TimeGenerated"])
    df = df.sort_values("TimeGenerated")

max_burnrate_df = df[(df["burnRate"] == df["burnRate"].max()) & (df["burnRate"].max() >= 2) ]

if max_burnrate_df.shape[0] > 0:
    max_burn_row = max_burnrate_df.iloc[0]
    print(max_burn_row)
# Out:
# TimeGenerated    2025-05-15 12:00:00+00:00
# totalRequests                       860108
# errorRequests                         2716
# SLI                               0.996842
# burnRate                          6.315486
# Name: 19, dtype: object

# %%
from datetime import timedelta
import pandas as pd
from pandas import Timedelta
from azure.monitor.query import LogsQueryStatus

def merge_with_role_and_time(base_df, other_df, tolerance="2s"):
    if base_df.empty or other_df.empty:
        return base_df

    # Ensure datetime format and sorting
    base_df["TimeGenerated"] = pd.to_datetime(base_df["TimeGenerated"])
    other_df["TimeGenerated"] = pd.to_datetime(other_df["TimeGenerated"])

    base_df.sort_values(["TimeGenerated", "AppRoleName"], inplace=True)
    other_df.sort_values(["TimeGenerated", "AppRoleName"], inplace=True)

    merged_chunks = []

    for role, base_group in base_df.groupby("AppRoleName"):
        other_group = other_df[other_df["AppRoleName"] == role]

        if other_group.empty:
            merged_chunks.append(base_group)
            continue

        # Drop overlapping columns except merge keys to allow overwrite
        overlapping = set(base_group.columns) & set(other_group.columns) - {"TimeGenerated", "AppRoleName"}
        other_group = other_group.drop(columns=overlapping)

        merged = pd.merge_asof(
            base_group,
            other_group,
            on="TimeGenerated",
            by="AppRoleName",
            direction="nearest",
            tolerance=Timedelta(tolerance)
        )

        merged_chunks.append(merged)

    return pd.concat(merged_chunks).sort_values("TimeGenerated")


# ========== LOGIC ==========

if max_burnrate_df.shape[0] > 0:

    spike_time = max_burn_row['TimeGenerated']
    start_time = spike_time - timedelta(minutes=5)
    end_time = spike_time + timedelta(minutes=5)
    timespan = (start_time, end_time)

    tables = {
        "AppRequests": f"""
            AppRequests
            | where TimeGenerated between (datetime({start_time.isoformat()}) .. datetime({end_time.isoformat()}))
            and AppRoleName contains "msonecloudapi-prod"
            and Success == false
            and toint(ResultCode) >= 500
            | project TimeGenerated, type="request", OperationName, Name, ResultCode, Duration = DurationMs, Success, AppRoleName
        """,
        "AppExceptions": f"""
            AppExceptions
            | where TimeGenerated between (datetime({start_time.isoformat()}) .. datetime({end_time.isoformat()}))
            and AppRoleName contains "msonecloudapi-prod"
            and ProblemId != "Microsoft.IdentityModel.S2S.S2SAuthenticationException"
            | project TimeGenerated, type="exception", OperationName, ProblemId, Message = OuterMessage, AppRoleName
        """,
        "AppTraces": f"""
            AppTraces
            | where TimeGenerated between (datetime({start_time.isoformat()}) .. datetime({end_time.isoformat()}))
            and AppRoleName contains "msonecloudapi-prod"
            and SeverityLevel >= 2
            | project TimeGenerated, type="trace", Message, SeverityLevel, AppRoleName
        """,
        "AppDependencies": f"""
            AppDependencies
            | where TimeGenerated between (datetime({start_time.isoformat()}) .. datetime({end_time.isoformat()}))
            and AppRoleName contains "msonecloudapi-prod"
            and Success == false
            | project TimeGenerated, type="dependency", Name, Target = Data, ResultCode, Success, Duration = DurationMs, AppRoleName, Server = AppRoleName
        """
    }

    # Query logs
    log_dict = {}
    for table_name, query in tables.items():
        resp = client.query_workspace(workspace_id, query, timespan=timespan)
        if resp.status == LogsQueryStatus.SUCCESS:
            tab = resp.tables[0]
            df = pd.DataFrame(tab.rows, columns=tab.columns)
            df["type"] = table_name  # optional, override type for traceability
            log_dict[table_name] = df

    # Merge logs with preference starting from AppRequests
    merged_logs = log_dict.get("AppRequests", pd.DataFrame())

    for table_name in ["AppExceptions", "AppTraces", "AppDependencies"]:
        other_df = log_dict.get(table_name, pd.DataFrame())
        merged_logs = merge_with_role_and_time(merged_logs, other_df, tolerance="2s")

    # Final formatting
    merged_logs.sort_values("TimeGenerated", inplace=True)
    merged_logs.reset_index(drop=True, inplace=True)

    if merged_logs.shape[0] > 30:
        merged_logs = merged_logs.sample(30)
        merged_logs.sort_values(["AppRoleName", "TimeGenerated"], inplace=True)
    # Output: merged_logs is your final DataFrame

# %%
merged_logs
# Out:
#                        TimeGenerated         type      OperationName  \
# 0   2025-05-15 11:55:00.619023+00:00  AppRequests  GET Product/Price
# 49  2025-05-15 11:55:58.432913+00:00  AppRequests  GET Product/Price
# 69  2025-05-15 11:56:27.109604+00:00  AppRequests  GET Product/Price
# 79  2025-05-15 11:56:36.866409+00:00  AppRequests  GET Product/Price
# 119 2025-05-15 11:57:34.384960+00:00  AppRequests  GET Product/Price
# 125 2025-05-15 11:57:43.452957+00:00  AppRequests  GET Product/Price
# 130 2025-05-15 11:57:57.196727+00:00  AppRequests  GET Product/Price
# 140 2025-05-15 11:58:09.938178+00:00  AppRequests  GET Product/Price
# 200 2025-05-15 11:59:16.222768+00:00  AppRequests  GET Product/Price
# 212 2025-05-15 11:59:29.241553+00:00  AppRequests  GET Product/Price
# 216 2025-05-15 11:59:44.521460+00:00  AppRequests  GET Product/Price
# 219 2025-05-15 11:59:50.211956+00:00  AppRequests  GET Product/Price
# 223 2025-05-15 11:59:52.295958+00:00  AppRequests  GET Product/Price
# 224 2025-05-15 11:59:52.297003+00:00  AppRequests  GET Product/Price
# 234 2025-05-15 12:00:05.451723+00:00  AppRequests  GET Product/Price
# 240 2025-05-15 12:00:14.063388+00:00  AppRequests  GET Product/Price
# 298 2025-05-15 12:01:27.527514+00:00  AppRequests  GET Product/Price
# 303 2025-05-15 12:01:29.475019+00:00  AppRequests  GET Product/Price
# 307 2025-05-15 12:01:30.657898+00:00  AppRequests  GET Product/Price
# 311 2025-05-15 12:01:33.486385+00:00  AppRequests  GET Product/Price
# 317 2025-05-15 12:01:50.969483+00:00  AppRequests  GET Product/Price
# 319 2025-05-15 12:01:55.173434+00:00  AppRequests  GET Product/Price
# 353 2025-05-15 12:02:46.668220+00:00  AppRequests  GET Product/Price
# 365 2025-05-15 12:03:19.397812+00:00  AppRequests  GET Product/Price
# 367 2025-05-15 12:03:23.870790+00:00  AppRequests  GET Product/Price
# 379 2025-05-15 12:03:46.365581+00:00  AppRequests  GET Product/Price
# 387 2025-05-15 12:03:53.520975+00:00  AppRequests  GET Product/Price
# 399 2025-05-15 12:04:04.612272+00:00  AppRequests  GET Product/Price
# 405 2025-05-15 12:04:06.741568+00:00  AppRequests  GET Product/Price
# 407 2025-05-15 12:04:08.168163+00:00  AppRequests  GET Product/Price
#
#                   Name ResultCode   Duration  Success  \
# 0    GET Product/Price        500    15.9157    False
# 49   GET Product/Price        500  1019.9718    False
# 69   GET Product/Price        500  1021.6910    False
# 79   GET Product/Price        500  1024.3574    False
# 119  GET Product/Price        500  1028.0079    False
# 125  GET Product/Price        500  1025.3491    False
# 130  GET Product/Price        500    12.7288    False
# 140  GET Product/Price        500  2017.5670    False
# 200  GET Product/Price        500    13.2668    False
# 212  GET Product/Price        500  1020.3536    False
# 216  GET Product/Price        500  3054.5759    False
# 219  GET Product/Price        500    19.3836    False
# 223  GET Product/Price        500    15.9321    False
# 224  GET Product/Price        500  1067.4059    False
# 234  GET Product/Price        500    17.0300    False
# 240  GET Product/Price        500  3041.9270    False
# 298  GET Product/Price        500    11.2425    False
# 303  GET Product/Price        500  1030.2615    False
# 307  GET Product/Price        500    14.1624    False
# 311  GET Product/Price        500    12.8289    False
# 317  GET Product/Price        500    14.2828    False
# 319  GET Product/Price        500    14.5746    False
# 353  GET Product/Price        500  2048.0897    False
# 365  GET Product/Price        500    15.0158    False
# 367  GET Product/Price        500  3054.4863    False
# 379  GET Product/Price        500    21.1191    False
# 387  GET Product/Price        500    11.6368    False
# 399  GET Product/Price        500    14.0134    False
# 405  GET Product/Price        500    12.2400    False
# 407  GET Product/Price        500  1025.1616    False
#
#                       AppRoleName  \
# 0    msonecloudapi-prod-japaneast
# 49   msonecloudapi-prod-japaneast
# 69   msonecloudapi-prod-japaneast
# 79   msonecloudapi-prod-japaneast
# 119  msonecloudapi-prod-japaneast
# 125  msonecloudapi-prod-japaneast
# 130  msonecloudapi-prod-japaneast
# 140  msonecloudapi-prod-japaneast
# 200  msonecloudapi-prod-japaneast
# 212  msonecloudapi-prod-japaneast
# 216  msonecloudapi-prod-japaneast
# 219  msonecloudapi-prod-japaneast
# 223  msonecloudapi-prod-japaneast
# 224  msonecloudapi-prod-japaneast
# 234  msonecloudapi-prod-japaneast
# 240  msonecloudapi-prod-japaneast
# 298  msonecloudapi-prod-japaneast
# 303  msonecloudapi-prod-japaneast
# 307  msonecloudapi-prod-japaneast
# 311  msonecloudapi-prod-japaneast
# 317  msonecloudapi-prod-japaneast
# 319  msonecloudapi-prod-japaneast
# 353  msonecloudapi-prod-japaneast
# 365  msonecloudapi-prod-japaneast
# 367  msonecloudapi-prod-japaneast
# 379  msonecloudapi-prod-japaneast
# 387  msonecloudapi-prod-japaneast
# 399  msonecloudapi-prod-japaneast
# 405  msonecloudapi-prod-japaneast
# 407  msonecloudapi-prod-japaneast
#
#                                              ProblemId  \
# 0    System.IO.FileNotFoundException at OneCloud.Da...
# 49   System.IO.FileNotFoundException at OneCloud.Da...
# 69   System.IO.FileNotFoundException at OneCloud.Da...
# 79   System.IO.FileNotFoundException at OneCloud.Da...
# 119  System.IO.FileNotFoundException at OneCloud.Da...
# 125  System.IO.FileNotFoundException at OneCloud.Da...
# 130  System.IO.FileNotFoundException at OneCloud.Da...
# 140  System.IO.FileNotFoundException at OneCloud.Da...
# 200  System.IO.FileNotFoundException at OneCloud.Da...
# 212  System.IO.FileNotFoundException at OneCloud.Da...
# 216                                                NaN
# 219  System.IO.FileNotFoundException at OneCloud.Da...
# 223  System.IO.FileNotFoundException at OneCloud.Da...
# 224  System.IO.FileNotFoundException at OneCloud.Da...
# 234  System.IO.FileNotFoundException at OneCloud.Da...
# 240  System.IO.FileNotFoundException at OneCloud.Da...
# 298  System.IO.FileNotFoundException at OneCloud.Da...
# 303  System.IO.FileNotFoundException at OneCloud.Da...
# 307  System.IO.FileNotFoundException at OneCloud.Da...
# 311  System.IO.FileNotFoundException at OneCloud.Da...
# 317  System.IO.FileNotFoundException at OneCloud.Da...
# 319  System.IO.FileNotFoundException at OneCloud.Da...
# 353  System.IO.FileNotFoundException at OneCloud.Da...
# 365  System.IO.FileNotFoundException at OneCloud.Da...
# 367                                                NaN
# 379  System.IO.FileNotFoundException at OneCloud.Da...
# 387  System.IO.FileNotFoundException at OneCloud.Da...
# 399  System.IO.FileNotFoundException at OneCloud.Da...
# 405  System.IO.FileNotFoundException at OneCloud.Da...
# 407  System.IO.FileNotFoundException at OneCloud.Da...
#
#                                                Message Target Server
# 0    Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 49   Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 69   Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 79   Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 119  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 125  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 130  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 140  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 200  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 212  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 216                                                NaN    NaN    NaN
# 219  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 223  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 224  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 234  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 240  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 298  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 303  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 307  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 311  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 317  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 319  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 353  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 365  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 367                                                NaN    NaN    NaN
# 379  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 387  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 399  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 405  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN
# 407  Could not load file or assembly 'OneCloud.Disp...    NaN    NaN

# %%
## Format for LLM
if max_burnrate_df.shape[0] > 0:
    lines = []
    for _, row in merged_logs.iterrows():
        summary = f"[{row['TimeGenerated']}] [{row['type']}] " + " | ".join(f"{k}={row[k]}" for k in row.index if k not in ['TimeGenerated', 'type'])
        lines.append(summary)

    log_context = "\n".join(lines[:30])  # Trim for LLM input

    log_context

# %%
# Prompt to LLM

if max_burnrate_df.shape[0] > 0:
    prompt_text = f"""
    A spike in error burn rate was detected between {start_time} and {end_time}.

    Here are logs across request, exception, trace, and dependency tables:

    {log_context}

    Analyze the root cause and recommend how to mitigate or fix the issue.
    """

# %%
#prompt_text

# %%
# Connect to LLM using my libraries
from utility.llm_factory import LLMFactory
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

if max_burnrate_df.shape[0] > 0:
    prompt = ChatPromptTemplate.from_messages([
            ("system", """
                You are a skilled and detail-oriented Site Reliability Engineering (SRE) assistant.
                Your primary goal is to help identify the root cause of incidents based on system logs and telemetry.

                - Summerize the issue in 1 bullet point only.
                - Focus on pinpointing the **source of the error**, **server name** and the **exact or approximate time** it occurred.
                - Keep the **root-cause** elaborated in 2-3 bullet points max.
                - If applicable, correlate related events across logs.
                - Keep your **mitigation and next steps** clear and concise (2-3 bullet points max).
                - Avoid vague conclusions. Use specific log details to support your reasoning.
            """),
            ("human", "{prompt_text}")
        ])

    # print(prompt)

    llm = LLMFactory.get_llm('openai')
    chain = prompt | llm | StrOutputParser()
    result = chain.invoke({"prompt_text": prompt_text })

    print("=== Incident Analysis by LLM ===\n")
    print(result)
# Out:
# === Incident Analysis by LLM ===
#
# **Summary**:
# The application (msonecloudapi-prod-japaneast) is failing to execute GET Product/Price operation due to a missing assembly 'OneCloud.DisplayProductCatalog.M365'. The issue started around 2025-05-15 11:55 and continued till at least 2025-05-15 12:04.
#
# **Root-Cause**:
# - The assembly 'OneCloud.DisplayProductCatalog.M365, Version=1.0.0.4281' is not found in the application's path which is resulting in a System.IO.FileNotFoundException.
# - This failure is preventing the proper functioning of the 'ProductController.CreateProductRequestFrom' method within the 'OneCloud.DataConnector.M365.Controllers' namespace in the 'msonecloudapi-prod-japaneast' application.
# - This could be due to an incorrect configuration or a missing deployment file in the server's file system.
#
# **Mitigation and Next steps**:
# 1. Check the deployment package to confirm if 'OneCloud.DisplayProductCatalog.M365, Version=1.0.0.4281' assembly was included during build and deploy process.
# 2. Validate the server file system to confirm if the assembly is present and accessible by application 'msonecloudapi-prod-japaneast'.
# 3. Correct the deployment package, configuration or file system to ensure application can find and load the required assembly.
# 4. Monitor the application after these changes to ensure the issue is resolved.
